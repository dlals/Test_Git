# %%
from matplotlib import pyplot

value = [50, 80, 72, 30]
pyplot.pie(value)
pyplot.show()

# %%
from matplotlib import pyplot

pyplot.rcParams['font.family'] = 'Malgun Gothic'
pyplot.rcParams['font.size'] = 12
pyplot.rcParams['figure.figsize'] = (12,8)

ratio = [3700, 2800, 1300, 590, 600]
labels = ['Apple', '삼성', 'LG', 'Sony', '기타']
colors = ['#ff6600', '#ff00ff', '#ffff00','#00ffff', '#0066ff']
explode = [0.0, 0.0, 0.0, 0.2, 0.1]

pyplot.figure()
pyplot.title('스마트폰 점유율')
pyplot.pie(ratio, labels = labels, colors = colors, explode= explode,
          autopct='%0.2f%%', shadow= False, startangle= 270)

pyplot.show()
pyplot.close()

# %%
from matplotlib import pyplot
value1 = [50, 80, 70, 30, 20, 10, 60]
value2 = [30, 60, 90, 120, 40, 50, 70]
pyplot.scatter(value1, value2)
pyplot.show()

# %%
from matplotlib import pyplot
from sample import tmp
from sample import qty

pyplot.rcParams['font.family'] = 'Malgun Gothic'
pyplot.rcParams['font.size'] = 12
pyplot.rcParams['figure.figsize'] = (12,8)

pyplot.figure()
pyplot.grid()
pyplot.scatter(tmp, qty, color='#DF01A5', marker='*', label='판매수량')
pyplot.legend()
pyplot.title('기온과 아이스크림 판매수량의 관계')
pyplot.xlabel('아이스크림 판매수량')
pyplot.ylabel('기온')


pyplot.show()
pyplot.close()
